# %%
import pandas as pd 
import requests

# %%
reponce=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4952ffb8344d664a7a03d242ab7b9cfc&language=en-US&page=1')

# %%
Movie_data=pd.DataFrame(reponce.json()["results"])[['id','title','overview',"release_date",'popularity','vote_average','vote_count']]

# %%
Movie_data.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     161.386
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     111.898
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      77.116
# 3  The true story of how businessman Oskar Schind...   1993-12-15      63.561
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      42.334
#
#    vote_average  vote_count
# 0         8.709       18947
# 1         8.704       24930
# 2         8.589       11440
# 3         8.571       14788
# 4         8.546        4276

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    reponce=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4952ffb8344d664a7a03d242ab7b9cfc&language=en-US&page={}'.format(i))
    tempMovies_data=pd.DataFrame(reponce.json()["results"])[['id','title','overview',"release_date",'popularity','vote_average','vote_count']]
    df= df.append(tempMovies_data,ignore_index=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\2862052293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(tempMovies_data,ignore_index=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\2862052293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(tempMovies_data,ignore_index=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\2862052293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(tempMovies_data,ignore_index=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14696\2862052293.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#           id                        title  \
# 0        238                The Godfather
# 1        278     The Shawshank Redemption
# 2        240        The Godfather Part II
# 3        424             Schindler's List
# 4      19404  Dilwale Dulhania Le Jayenge
# ...      ...                          ...
# 8555  763164                         Apex
# 8556  109091                The Counselor
# 8557  525460                 Welcome Home
# 8558   17825          The 11 Commandments
# 8559    9714                 Home Alone 3
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('tempMovies_data.csv')
